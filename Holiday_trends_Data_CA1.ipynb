# %% [markdown]
# # Recent Holiday Trends and Traveller Behaviour Survey

# %% [markdown]
# ## The purpose of this survey is to explore recent holiday trends and traveller behaviour. This survey forms part of an academic project for the Statistical Techniques for Data Analytics module.

# %%
import pandas as pd

# %% [markdown]
# ## Load the Dataset

# %%
df_Holidays = pd.read_csv("Holiday_trends_Data_CA1.csv")

# %% [markdown]
# ### Display first 5 rows, to ensure the data has correctly loaded

# %%
df_Holidays.head(5)
# Out:
#           Timestamp \nWhat age range are you in?  \
# 0  25/09/2026 12:25                          65+
# 1  25/09/2026 12:25                        55-64
# 2  25/09/2026 12:27                          65+
# 3  25/09/2026 12:29                          65+
# 4  25/09/2026 12:32                        25-34
#
#                     Was your holiday   \
# 0  A Holiday abroad (outside Ireland)
# 1  A Holiday abroad (outside Ireland)
# 2  A Holiday abroad (outside Ireland)
# 3  A Holiday abroad (outside Ireland)
# 4  A Holiday abroad (outside Ireland)
#
#           What was the main purpose of your Holiday  \
# 0  To attend an event (concert, Football match etc)
# 1                              Beach Holiday abroad
# 2                              Beach Holiday abroad
# 3                                        City Break
# 4                                             Other
#
#   How did you book your holiday  \
# 0   Independently Booked online
# 1             A package holiday
# 2   Independently Booked online
# 3   Independently Booked online
# 4   Independently Booked online
#
#                          How recent was this holiday  \
# 0  Greater than 3 months ago but within the last ...
# 1                                   In last 3 months
# 2                                   In last 3 months
# 3  Greater than 3 months ago but within the last ...
# 4  Greater than 3 months ago but within the last ...
#
#   How would you describe your holiday type  \
# 0                   A holiday with friends
# 1                         A family holiday
# 2                         A family holiday
# 3                   A holiday with friends
# 4                   A holiday with friends
#
#    How many people were in your travel group?  \
# 0                                           6
# 1                                           2
# 2                                           4
# 3                                           6
# 4                                           3
#
#    Approximately how much did your accommodation cost per room per night (€)?  \
# 0                                                100
# 1                                                150
# 2                                                 70
# 3                                                 50
# 4                                                115
#
#    How many nights did your holiday last?  \
# 0                                       3
# 1                                       5
# 2                                      28
# 3                                       3
# 4                                       6
#
#    Overall Holiday Cost - Approximate total spend for all travellers (€), including  cost of holiday + daily spending.  \
# 0                                                800
# 1                                               3000
# 2                                               4800
# 3                                                500
# 4                                               3000
#
#    How satisfied were you with your holiday overall?  \
# 0                                                  5
# 1                                                  3
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
#   Would You Take This Type of Holiday Again? Did You Travel by Air?  \
# 0                                        Yes                    Yes
# 1                                        Yes                    Yes
# 2                                        Yes                     No
# 3                                        Yes                    Yes
# 4                                        Yes                    Yes
#
#    How many holidays have you taken in the last 12 months?
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  2
# 4                                                  3

# %% [markdown]
# ###  Trim any spaces from the headings

# %%
df_Holidays.columns = df_Holidays.columns.str.strip()

# %% [markdown]
# # Rename columns to make it more readable

# %%
df_Holidays = df_Holidays.rename(columns={
    "Timestamp": "Timestamp",
    "What age range are you in": "Age_Range",
    "Was your holiday": "Holiday_Location",
    "What was the main purpose of your Holiday": "Holiday_Purpose",
    "How did you book your holiday": "Booking_Method",
    "How recent was this holiday": "Holiday_Recency",
    "How would you describe your holiday type": "Holiday_Type",
    "How many people were in your travel group?": "Group_Size",
    "Approximately how much did your accommodation cost per room per night (€)?": "Accommodation_Cost",
    "How many nights did your holiday last?": "Holiday_Length",
    "Overall Holiday Cost - Approximate total spend for all travellers (€), including  cost of holiday + daily spending.": "Total_Cost",
    "How satisfied were you with your holiday overall?": "Satisfaction",
    "Would You Take This Type of Holiday Again?": "Holiday_Again",
    "Did You Travel by Air?": "Travel_By_Air",
    "How many holidays have you taken in the last 12 months?": "Holidays_Last_12_Months"
    } 
    )

# %% [markdown]
# ## Show Statistics on the csv file

# %% [markdown]
# ###  Descriptive Statistics

# %%
df_Holidays.describe().T
# Out:
#                          count         mean          std    min    25%  \
# Group_Size                48.0     3.541667     1.923631    1.0    2.0
# Accommodation_Cost        48.0   221.104167   575.275114   10.0   77.5
# Holiday_Length            48.0     7.562500     5.675278    2.0    4.0
# Total_Cost                48.0  2427.083333  1683.776099  200.0  950.0
# Satisfaction              48.0     4.416667     0.678965    3.0    4.0
# Holidays_Last_12_Months   48.0     2.520833     1.129669    1.0    2.0
#
#                             50%      75%     max
# Group_Size                  3.0     4.00    10.0
# Accommodation_Cost        112.5   150.00  4000.0
# Holiday_Length              7.0     7.25    28.0
# Total_Cost               2000.0  3125.00  6000.0
# Satisfaction                5.0     5.00     5.0
# Holidays_Last_12_Months     2.0     3.00     5.0

# %%
df_Holidays.shape
# Out:
# (48, 15)

# %% [markdown]
# ### Check for missing values

# %%
df_Holidays.isnull().sum()
# Out:
# Timestamp                     0
# What age range are you in?    0
# Holiday_Location              0
# Holiday_Purpose               0
# Booking_Method                0
# Holiday_Recency               0
# Holiday_Type                  0
# Group_Size                    0
# Accommodation_Cost            0
# Holiday_Length                0
# Total_Cost                    0
# Satisfaction                  0
# Holiday_Again                 0
# Travel_By_Air                 0
# Holidays_Last_12_Months       0
# dtype: int64

# %% [markdown]
# ### No missing values were identified in the dataset. Therefore no records required removal

# %% [markdown]
# ### Show Skewness of the data

# %%
df_Holidays.skew(numeric_only=True)
# Out:
# Group_Size                 1.421523
# Accommodation_Cost         6.337030
# Holiday_Length             2.474319
# Total_Cost                 0.621934
# Satisfaction              -0.748730
# Holidays_Last_12_Months    0.500526
# dtype: float64

# %% [markdown]
# ### Accomodation Costs shows a positive skewness (6.33), indicating the presence of extreme observations. In Descriptive Statistics, the average accomodation cost is €221.10, the maximum recorded value is €4,000, suggesting a small number of very expensive holidays are influencing the overall distribution

# %% [markdown]
# ### Holiday Length also demonstrates a positive skewness of 2.47.  While most holidays show an average of 7.5 days, the maximum holiday length of 28 days was recorded, again this outlier is influencing the overall distribution

# %% [markdown]
# ### The Satisfaction skewness of (-0.74) indicates that responses are clustered towards the higher end of the rating scale.  This is suggesting that people were generally satisfied with their holiday experience

# %%
df_Holidays.median(numeric_only=True)
# Out:
# Group_Size                    3.0
# Accommodation_Cost          112.5
# Holiday_Length                7.0
# Total_Cost                 2000.0
# Satisfaction                  5.0
# Holidays_Last_12_Months       2.0
# dtype: float64

# %% [markdown]
# ### See above median values.  Accomodation costs has a median of €112.50, however the mean is €221.10.  This further demonstrates the impact of extreme values on the distribution
